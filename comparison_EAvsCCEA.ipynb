# %% [markdown]
# **Comparación de los resultados obtenidos entre el EA y el CCEA**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
len(range(0,250,8))
# Out:
# 32

# %%
plt.figure(figsize=(10,6))

ev_ea = np.load("obj_evolution_EA.npy")
ev_ccea = np.load("obj_evolution_CCEA.npy")

plt.plot(range(0,len(ev_ea)), ev_ea, label='EA')
plt.xlabel('Iteraciones') 
plt.ylabel('Energía') 

plt.plot(range(0,len(ev_ccea)*8,8), ev_ccea, label='CCEA')
plt.xlabel('Iteraciones') 
plt.ylabel('Energía') 

plt.title('EA vs CCEA')
plt.legend()
plt.show()

# %%
# Energía total
np.sum(np.load("weights.npy"))/2
# Out:
# 39652.97265625

# %%
plt.figure(figsize=(10,6))

ev_ea = np.load("obj_evolution_EA_2.npy")
ev_ccea = np.load("obj_evolution_CCEA_2.npy")

plt.plot(range(0,len(ev_ea)), ev_ea, label='EA')
plt.xlabel('Iteraciones') 
plt.ylabel('Energía') 

plt.plot(range(0,len(ev_ccea)*8,8), ev_ccea, label='CCEA')
plt.xlabel('Iteraciones') 
plt.ylabel('Energía') 

plt.title('EA vs CCEA')
plt.legend()
plt.show()

# %%
# Energía total
np.sum(np.load("weights_2.npy"))/2
# Out:
# 3996690.75
